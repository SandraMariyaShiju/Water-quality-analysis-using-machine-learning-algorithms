# %%
import pandas as pd

# %%
df = pd.read_excel('TIME_SERIES.xlsx')
df
# Out:
#                 State  Potable Count  Clean Count  Year Region
# 0              KERALA             25           68  2017  South
# 1           MEGHALAYA             12           27  2017   East
# 2                 GOA              7           17  2017   West
# 3              PUNJAB              4           13  2017  North
# 4    HIMACHAL PRADESH              3            6  2017  North
# ..                ...            ...          ...   ...    ...
# 83             ODISHA              0           14  2021   East
# 84          KARNATAKA              0            6  2021  South
# 85  HIMACHAL\nPRADESH              0            6  2021  North
# 86     ANDHRA PRADESH              0            6  2021  South
# 87         PUDUCHERRY              0            5  2021  South
#
# [88 rows x 5 columns]

# %%
#1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

state_to_plot = 'KERALA'
state_data = df[df['State'] == state_to_plot]

years = state_data['Year']
potable_count = state_data['Potable Count']
clean_count = state_data['Clean Count']

plt.figure(figsize=(10, 6))
plt.plot(years, potable_count, label='Potable Count', marker='o', color='g')
plt.plot(years, clean_count, label='Clean Count', marker='+', color='b')

plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(np.arange(min(df['Year']), max(df['Year'])+1,step=1))
plt.title(f'{state_to_plot} Potable and Clean Count Over the Years')
plt.legend()
plt.show()

# %%
#2
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
states = df['State'].unique()
for state in states:
    state_data = df[df['State'] == state]
    years = state_data['Year']
    potable_count = state_data['Potable Count']
    plt.plot(years, potable_count, label=f'{state} - Potable Count', marker='o')

plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(np.arange(min(df['Year']), max(df['Year'])+1,step=1))
plt.title('Potable Count for All States Over the Years')
plt.legend(bbox_to_anchor=(1, 1.01))
plt.show()

# %%
#3
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
states = df['State'].unique()
for state in states:
    state_data = df[df['State'] == state]
    years = state_data['Year']
    clean_count = state_data['Clean Count']
    plt.plot(years, clean_count, label=f'{state} - Clean Count', marker='o')

plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(np.arange(min(df['Year']), max(df['Year'])+1,step=1))
plt.title('Clean Count for All States Over the Years')
plt.legend(bbox_to_anchor=(1, 1.01))
plt.show()

# %%
#4
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

south_data = df[df['Region'] == 'South']
south_states = south_data['State'].unique()

plt.figure(figsize=(12, 8))
for state in south_states:
    state_data = south_data[south_data['State'] == state]
    years = state_data['Year']
    potable_count = state_data['Potable Count']
    clean_count = state_data['Clean Count']

    # Plot "Potable Count" for each state in the North
    plt.plot(years, potable_count, label=f'{state} - Potable Count', marker='o')
    plt.plot(years, clean_count, label=f'{state} - Clean Count', marker='o')

# Add labels and a legend
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(np.arange(min(df['Year']), max(df['Year'])+1,step=1))
plt.title('Potable and Clean Count for States in the South Over the Years')
plt.legend(bbox_to_anchor=(1, 1.01))
plt.show()

# %%
#5
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

east_data = df[df['Region'] == 'East']
east_states = east_data['State'].unique()

plt.figure(figsize=(12, 8))
for state in east_states:
    state_data = east_data[east_data['State'] == state]
    years = state_data['Year']
    potable_count = state_data['Potable Count']
    clean_count = state_data['Clean Count']

    # Plot "Potable Count" for each state in the North
    plt.plot(years, potable_count, label=f'{state} - Potable Count', marker='o')
    plt.plot(years, clean_count, label=f'{state} - Clean Count', marker='o')

# Add labels and a legend
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(np.arange(min(df['Year']), max(df['Year'])+1,step=1))
plt.title('Potable and Clean Count for States in the East Over the Years')
plt.legend(bbox_to_anchor=(1, 1.01))
plt.show()

# %%
#6
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

west_data = df[df['Region'] == 'West']
west_states = west_data['State'].unique()

plt.figure(figsize=(12, 8))
for state in west_states:
    state_data = west_data[west_data['State'] == state]
    years = state_data['Year']
    potable_count = state_data['Potable Count']
    clean_count = state_data['Clean Count']

    # Plot "Potable Count" for each state in the North
    plt.plot(years, potable_count, label=f'{state} - Potable Count', marker='o')
    plt.plot(years, clean_count, label=f'{state} - Clean Count', marker='o')

# Add labels and a legend
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(np.arange(min(df['Year']), max(df['Year'])+1,step=1))
plt.title('Potable and Clean Count for States in the West Over the Years')
plt.legend(bbox_to_anchor=(1, 1.01))
plt.show()

# %%
#7
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

north_data = df[df['Region'] == 'North']
north_states = north_data['State'].unique()

plt.figure(figsize=(12, 8))
for state in north_states:
    state_data = north_data[north_data['State'] == state]
    years = state_data['Year']
    potable_count = state_data['Potable Count']
    clean_count = state_data['Clean Count']

    # Plot "Potable Count" for each state in the North
    plt.plot(years, potable_count, label=f'{state} - Potable Count', marker='o')
    plt.plot(years, clean_count, label=f'{state} - Clean Count', marker='o')

# Add labels and a legend
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(np.arange(min(df['Year']), max(df['Year'])+1,step=1))
plt.title('Potable and Clean Count for States in the North Over the Years')
plt.legend(bbox_to_anchor=(1, 1.01))
plt.show()
